# %% [markdown]
# ## 1. Import CSV

# %%
# ensure pandas is installed in this notebook environment
# %pip install pandas

import pandas as pd
df = pd.read_csv('export_csv/customer.csv')
print(df.head(10))
# Out:
#                                 user_id  age  gender
# 0  14bd44dc-00a9-459b-bfa1-14716fff82b7   25  Female
# 1  8fb61f72-a041-454e-a90c-6ac54aa20ee8   21  Female
# 2  a4b531bd-7f4c-4cfa-80d3-3a876672f7fd   36    Male
# 3  17d524d6-7195-4305-9a13-516104cc98b0   34  Female
# 4  a6d6da71-ab57-49ec-8313-34d231aaa06f   27    Male
# 5  44aa0743-9e05-49df-8585-c1c74fac5974   18    Male
# 6  383d92e8-df19-4510-bb98-1d2de70cfba9   18  Female
# 7  36133df6-95a8-4887-a399-152a88f5013a   36  Female
# 8  5a21a7bd-8980-43dd-8a10-52491e34d895   32  Female
# 9  c391f22a-122a-401d-81d8-bb9be3b048ea   24    Male

# %%
import pandas as pd

df = pd.read_csv('export_csv/product.csv')
print(df.head(10))
# Out:
#    product_id  brand_id  cat1_id  cat2_id  category_id  product_sku  \
# 0        5358       454        5       43          195    2405P6355
# 1        5068       461        4       31          161    2405P6065
# 2       16748      1275        3       24          149  2411P000137
# 3        4568       470        3       21          129    2405P5565
# 4        2092        76        3       21          132    2405P3089
# 5         491       116        7       64          264    2405P1488
# 6        1720       233        3       21          133    2405P2717
# 7       21311      1128        6       53          231  2504P000253
# 8        2536       686        1       12           95    2405P3533
# 9       24371      1504        3       29          341  2509P000629
#
#    product_amount  product_discount
# 0        278000.0             39963
# 1       1194000.0             84183
# 2        220000.0             44000
# 3        364000.0            106327
# 4        254000.0             33957
# 5       1029000.0            271800
# 6        138000.0             15999
# 7        978000.0             76640
# 8       1258000.0            172800
# 9             NaN                 0

# %%
import pandas as pd

df = pd.read_csv('export_csv/product_category.csv')
print(df.head(10))
# Out:
#    category_id                    category_name
# 0          420                 Giày Bóng Chuyền
# 1          194     Móc Treo, Thùng đựng quần áo
# 2          138                     Tã người lớn
# 3          222     Quà tặng nhà cửa và đời sống
# 4          172                   Thực phẩm khác
# 5          270           Máy lạnh, Máy điều hòa
# 6          136       Thiết bị chăm sóc sức khỏe
# 7          245                          Áo kiểu
# 8           64            Thiết bị điện nhà bếp
# 9           85  Qùa tặng thể thao dã ngoại khác

# %%
import pandas as pd

df = pd.read_csv('export_csv/sale_order.csv')
print(df.head(10))
# Out:
#                           sale_order_id                               user_id  \
# 0  d6ad447a-1378-4e25-8305-7e90c87789c6  14bd44dc-00a9-459b-bfa1-14716fff82b7
# 1  1667cef4-ca7f-425e-9f45-59c833eb8452  8fb61f72-a041-454e-a90c-6ac54aa20ee8
# 2  51ee75c8-7ca4-44f0-8295-e22322115977  a4b531bd-7f4c-4cfa-80d3-3a876672f7fd
# 3  d1e0c045-a93e-47c7-b951-43f3aabba26f  17d524d6-7195-4305-9a13-516104cc98b0
# 4  82770789-8a8d-43ff-aea8-d264b64eac09  a6d6da71-ab57-49ec-8313-34d231aaa06f
# 5  1e5b5741-dc6c-477c-aee1-f3f2b11b99dc  44aa0743-9e05-49df-8585-c1c74fac5974
# 6  7e9dcd10-8581-4a90-9c78-6420a4dd64e3  44aa0743-9e05-49df-8585-c1c74fac5974
# 7  e82c9dc6-ab0b-4299-b092-53d59bbc6139  383d92e8-df19-4510-bb98-1d2de70cfba9
# 8  7aac3be3-aeed-445f-ae7f-a3d11521d6f9  36133df6-95a8-4887-a399-152a88f5013a
# 9  aa1c7401-a0f0-4cb1-89c2-3b44012bd80f  36133df6-95a8-4887-a399-152a88f5013a
#
#    channel_id  merchant_id  status  order_discount  shipping_fee  \
# 0           7          246       0           40000             0
# 1           1          246       0               0         23000
# 2           1          246       0           70000             0
# 3           1          246       0           32090         28000
# 4           3          246       0               0         28000
# 5           3          246       0           97000         23000
# 6           3          246       0          101000         23000
# 7           1          246       1           40000             0
# 8           3          246       0               0             0
# 9           3          246       0           20000         35000
#
#    shipping_discount  order_amount        order_date  \
# 0                  0      780000.0  12/31/2025 23:59
# 1                  0      312000.0  12/31/2025 23:57
# 2                  0      630000.0  12/31/2025 23:54
# 3                  0      234910.0  12/31/2025 23:53
# 4                  0      107000.0  12/31/2025 23:53
# 5                  0      790000.0  12/31/2025 23:52
# 6                  0      836000.0  12/31/2025 23:46
# 7                  0      780000.0  12/31/2025 23:45
# 8                  0      655500.0  12/31/2025 23:39
# 9                  0      436000.0  12/31/2025 23:33
#
#                          shipping_street       shipping_ward_name  \
# 0                                 Hà Đới            Xã Tiên Thanh
# 1                55 ngõ 2 Khuất Duy Tiến  Phường Thanh Xuân Trung
# 2  Cafe võng 4 nàng tiên nguyễn thị trọn            Xã Vĩnh Lộc A
# 3                           Thôn Đạo Khê            Xã Trung Hưng
# 4                    10 nguyễn thị giang        Phường Thanh Bình
# 5      T- Coffe S902 Vinhomes Grand Park         Phường Long Bình
# 6      T- Coffe S902 Vinhomes Grand Park         Phường Long Bình
# 7                                 Hà Đới            Xã Tiên Thanh
# 8                 292 đường nguyễn hoàng         Phường Thạc Gián
# 9                 292 đường nguyễn hoàng         Phường Thạc Gián
#
#   shipping_district_name shipping_province_name
# 0        Huyện Tiên Lãng              Hải Phòng
# 1        Quận Thanh Xuân                 Hà Nội
# 2       Huyện Bình Chánh            Hồ Chí Minh
# 3           Huyện Yên Mỹ               Hưng Yên
# 4     Thành phố Biên Hòa               Đồng Nai
# 5      Thành phố Thủ Đức            Hồ Chí Minh
# 6      Thành phố Thủ Đức            Hồ Chí Minh
# 7        Huyện Tiên Lãng              Hải Phòng
# 8         Quận Thanh Khê                Đà Nẵng
# 9         Quận Thanh Khê                Đà Nẵng

# %%
import pandas as pd

df = pd.read_csv('export_csv/sale_order_line.csv')
print(df.head(10))
# Out:
#    line_id                         sale_order_id  product_id  is_gift
# 0   237023  2dcf8a24-47d3-4eae-b7f4-82e0f91f024b       18918    False
# 1   254206  4db9f2a2-1a46-4929-abc5-5971fb493341        1014    False
# 2   237109  ccda3682-64d8-4549-aded-4a382e97c64d       15450    False
# 3   234997  57f60526-716e-4167-aa08-e1406a204c4c        1160    False
# 4   244152  64660773-bd82-43d5-a45e-67070bd72348       13785    False
# 5   244222  36d5c090-e9aa-4dec-bba8-3ad663c3dbd1        1000    False
# 6   244223  36d5c090-e9aa-4dec-bba8-3ad663c3dbd1        1011     True
# 7   248860  5743bf52-b774-4066-beaa-6ae1e3976410       23383    False
# 8   250208  fd8cea6a-3d0d-4d9b-8c66-7fd03a6c7b79       14754    False
# 9   250270  0c51ec99-63eb-437c-9a41-971bdd49db1f       16066    False

# %% [markdown]
# ## 2. Statistics

# %%
import pandas as pd

files = [
    "export_csv/customer.csv",
    "export_csv/product.csv",
    "export_csv/product_category.csv",
    "export_csv/sale_order.csv",
    "export_csv/sale_order_line.csv",
]

dfs = {}

for file in files:
    dfs[file] = pd.read_csv(file)

for name, df in dfs.items():
    print(f"=== {name} ===")
    display(df.describe(include="all"))
# Out:
# === export_csv/customer.csv ===
#                                      user_id           age  gender
# count                                  68262  68262.000000   68262
# unique                                 68262           NaN       2
# top     14bd44dc-00a9-459b-bfa1-14716fff82b7           NaN  Female
# freq                                       1           NaN   40793
# mean                                     NaN     29.844423     NaN
# std                                      NaN      7.537379     NaN
# min                                      NaN     18.000000     NaN
# 25%                                      NaN     24.000000     NaN
# 50%                                      NaN     30.000000     NaN
# 75%                                      NaN     35.000000     NaN
# max                                      NaN     60.000000     NaN
# === export_csv/product.csv ===
#           product_id     brand_id      cat1_id      cat2_id  category_id  \
# count    1653.000000  1653.000000  1653.000000  1653.000000  1653.000000
# unique           NaN          NaN          NaN          NaN          NaN
# top              NaN          NaN          NaN          NaN          NaN
# freq             NaN          NaN          NaN          NaN          NaN
# mean    10560.776770   653.316999     3.416818    29.538415   165.473684
# std      7702.196278   393.286152     1.554072    15.950036    54.670863
# min         2.000000     2.000000     1.000000    11.000000    90.000000
# 25%      2411.000000   343.000000     3.000000    21.000000   133.000000
# 50%     10600.000000   611.000000     3.000000    25.000000   151.000000
# 75%     16529.000000   886.000000     4.000000    35.000000   181.000000
# max     29225.000000  1602.000000     8.000000   384.000000   391.000000
#
#        product_sku  product_amount  product_discount
# count         1653    1.578000e+03      1.653000e+03
# unique        1653             NaN               NaN
# top      2405P6355             NaN               NaN
# freq             1             NaN               NaN
# mean           NaN    1.664074e+07      4.139213e+05
# std            NaN    5.486605e+08      3.401381e+06
# min            NaN    4.600000e+04      0.000000e+00
# 25%            NaN    3.150000e+05      5.000000e+04
# 50%            NaN    5.367000e+05      8.430000e+04
# 75%            NaN    1.060000e+06      1.651260e+05
# max            NaN    2.167830e+10      9.536000e+07
# === export_csv/product_category.csv ===
#         category_id        category_name
# count    420.000000                  420
# unique          NaN                  335
# top             NaN  Quà tặng Thời trang
# freq            NaN                    6
# mean     210.500000                  NaN
# std      121.387808                  NaN
# min        1.000000                  NaN
# 25%      105.750000                  NaN
# 50%      210.500000                  NaN
# 75%      315.250000                  NaN
# max      420.000000                  NaN
# === export_csv/sale_order.csv ===
#                                sale_order_id  \
# count                                 374181
# unique                                374181
# top     d6ad447a-1378-4e25-8305-7e90c87789c6
# freq                                       1
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
#
#                                      user_id     channel_id  merchant_id  \
# count                                 374181  374181.000000     374181.0
# unique                                 67536            NaN          NaN
# top     69fca63d-b71b-4ebf-80c4-a130fb3a6c4f            NaN          NaN
# freq                                     822            NaN          NaN
# mean                                     NaN       3.481660        246.0
# std                                      NaN       2.739606          0.0
# min                                      NaN       1.000000        246.0
# 25%                                      NaN       1.000000        246.0
# 50%                                      NaN       3.000000        246.0
# 75%                                      NaN       6.000000        246.0
# max                                      NaN       8.000000        246.0
#
#                status  order_discount   shipping_fee  shipping_discount  \
# count   374181.000000    3.741810e+05  374181.000000      374181.000000
# unique            NaN             NaN            NaN                NaN
# top               NaN             NaN            NaN                NaN
# freq              NaN             NaN            NaN                NaN
# mean         0.582723    8.796153e+04   11907.071711       12495.454339
# std          0.493110    1.515663e+06   19127.228000       16599.635184
# min          0.000000    0.000000e+00       0.000000           0.000000
# 25%          0.000000    0.000000e+00       0.000000           0.000000
# 50%          1.000000    2.000000e+04    8000.000000       15000.000000
# 75%          1.000000    5.700000e+04   19000.000000       20000.000000
# max          1.000000    9.536000e+07  455000.000000      384000.000000
#
#         order_amount       order_date shipping_street shipping_ward_name  \
# count   3.741810e+05           374181          374181             374181
# unique           NaN           256564           40437               4524
# top              NaN  3/22/2025 15:00      22 Láng Hạ     Phường Láng Hạ
# freq             NaN              222            3004              11434
# mean    5.856199e+07              NaN             NaN                NaN
# std     1.077657e+09              NaN             NaN                NaN
# min     0.000000e+00              NaN             NaN                NaN
# 25%     2.962800e+05              NaN             NaN                NaN
# 50%     7.170000e+05              NaN             NaN                NaN
# 75%     1.890000e+06              NaN             NaN                NaN
# max     4.335660e+10              NaN             NaN                NaN
#
#        shipping_district_name shipping_province_name
# count                  374181                 374181
# unique                    666                     64
# top              Quận Đống Đa                 Hà Nội
# freq                    23277                 141235
# mean                      NaN                    NaN
# std                       NaN                    NaN
# min                       NaN                    NaN
# 25%                       NaN                    NaN
# 50%                       NaN                    NaN
# 75%                       NaN                    NaN
# max                       NaN                    NaN
# === export_csv/sale_order_line.csv ===
#               line_id                         sale_order_id     product_id  \
# count   510550.000000                                510550  510550.000000
# unique            NaN                                374181            NaN
# top               NaN  896d51c0-8346-4173-b16f-d43a371f923c            NaN
# freq              NaN                                    68            NaN
# mean    352478.768828                                   NaN    8053.572929
# std     155103.225048                                   NaN    7323.446609
# min      70278.000000                                   NaN       2.000000
# 25%     222088.250000                                   NaN    1182.000000
# 50%     358085.500000                                   NaN    5638.000000
# 75%     485722.750000                                   NaN   14337.000000
# max     613360.000000                                   NaN   29225.000000
#
#        is_gift
# count   510550
# unique       2
# top      False
# freq    476306
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %% [markdown]
# ## 3. Data Types

# %%
for file, df in dfs.items():
    print(f"=== {file} ===")
    display(df.dtypes)
# Out:
# === export_csv/customer.csv ===
# user_id      str
# age        int64
# gender       str
# dtype: object
# === export_csv/product.csv ===
# product_id            int64
# brand_id              int64
# cat1_id               int64
# cat2_id               int64
# category_id           int64
# product_sku             str
# product_amount      float64
# product_discount      int64
# dtype: object
# === export_csv/product_category.csv ===
# category_id      int64
# category_name      str
# dtype: object
# === export_csv/sale_order.csv ===
# sale_order_id                 str
# user_id                       str
# channel_id                  int64
# merchant_id                 int64
# status                      int64
# order_discount              int64
# shipping_fee                int64
# shipping_discount           int64
# order_amount              float64
# order_date                    str
# shipping_street               str
# shipping_ward_name            str
# shipping_district_name        str
# shipping_province_name        str
# dtype: object
# === export_csv/sale_order_line.csv ===
# line_id          int64
# sale_order_id      str
# product_id       int64
# is_gift           bool
# dtype: object

# %% [markdown]
# ## 4. Find missing values

# %%
import pandas as pd

for file in files:
    missing = pd.read_csv(file).isnull().sum()
    print(f"\n=== {file} ===")
    print(missing)
# Out:
# === export_csv/customer.csv ===
# user_id    0
# age        0
# gender     0
# dtype: int64
#
# === export_csv/product.csv ===
# product_id           0
# brand_id             0
# cat1_id              0
# cat2_id              0
# category_id          0
# product_sku          0
# product_amount      75
# product_discount     0
# dtype: int64
#
# === export_csv/product_category.csv ===
# category_id      0
# category_name    0
# dtype: int64
#
# === export_csv/sale_order.csv ===
# sale_order_id             0
# user_id                   0
# channel_id                0
# merchant_id               0
# status                    0
# order_discount            0
# shipping_fee              0
# shipping_discount         0
# order_amount              0
# order_date                0
# shipping_street           0
# shipping_ward_name        0
# shipping_district_name    0
# shipping_province_name    0
# dtype: int64
#
# === export_csv/sale_order_line.csv ===
# line_id          0
# sale_order_id    0
# product_id       0
# is_gift          0
# dtype: int64

# %%
# Check for duplicates in each DataFrame
for file, df in dfs.items():
    duplicates = df.duplicated().sum()
    print(f"\n=== {file} ===")
    print(f"Number of duplicate rows: {duplicates}")
# Out:
# === export_csv/customer.csv ===
# Number of duplicate rows: 0
#
# === export_csv/product.csv ===
# Number of duplicate rows: 0
#
# === export_csv/product_category.csv ===
# Number of duplicate rows: 0
#
# === export_csv/sale_order.csv ===
# Number of duplicate rows: 0
#
# === export_csv/sale_order_line.csv ===
# Number of duplicate rows: 0

# %%
# remove nulls and duplicates
for file, df in dfs.items():
    df.dropna(inplace=True)
    df.drop_duplicates(inplace=True)

# %% [markdown]
# ## 5. Create a distrbution and box plot

# %%
# %pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: tzdata in c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Sale Order

# %%
# draw boxplot and distribution plot for each numeric column in sale_order.csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sale_order_df = pd.read_csv('export_csv/sale_order.csv')    
numeric_cols = sale_order_df.select_dtypes(include=['float64', 'int64']).columns
numeric_cols = [col for col in numeric_cols if col != 'channel_id' and col != 'merchant_id' and col != 'status']  # exclude id columns
for col in numeric_cols:
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 1, 1)
    sns.boxplot(x=sale_order_df[col])
    plt.title(f'Boxplot of {col}')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Product

# %%
# draw boxplot and distribution plot for each numeric column in product.csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

product_df = pd.read_csv('export_csv/product.csv')
numeric_cols = product_df.select_dtypes(include=['float64', 'int64']).columns.difference([
    'product_id',
    'brand_id',
    'cat1_id',
    'cat2_id',
    'category_id',
    'product_sku'
])


for col in numeric_cols:
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 1, 1)
    sns.boxplot(x=product_df[col])
    plt.title(f'Boxplot of {col}')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Age

# %%
# biểu đồ phân bố khách hàng theo tuổi
import matplotlib.pyplot as plt
import seaborn as sns
customer_df = pd.read_csv('export_csv/customer.csv')
sns.histplot(customer_df['age'], bins=20, kde=True)
plt.title('Phan bo khach hang theo tuoi')
plt.xlabel('Tuoi')
plt.show()

# %% [markdown]
# ## 6. Bar chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math

product_df = pd.read_csv("export_csv/product.csv")
product_category_df = pd.read_csv("export_csv/product_category.csv")

merged_df = product_df.merge(
    product_category_df[['category_id', 'category_name']],
    on='category_id',
    how='left'
)

category_counts = (
    merged_df.groupby(['category_id', 'category_name'])
    .size()
    .reset_index(name='product_count')
    .sort_values(by='category_id')
)

category_counts['category_name'] = category_counts['category_name'].fillna('Unknown')
category_counts['label'] = (
    category_counts['category_id'].astype(str) + ' - ' + category_counts['category_name']
)

n = len(category_counts)
chunk_size = math.ceil(n / 3)

chunks = [
    category_counts.iloc[i:i + chunk_size]
    for i in range(0, n, chunk_size)
]

fig, axes = plt.subplots(3, 1, figsize=(16, 18))

for i, chunk in enumerate(chunks):
    sns.barplot(data=chunk, x='label', y='product_count', ax=axes[i])
    axes[i].set_title(f'So luong san pham theo category - Phan {i+1}')
    axes[i].set_xlabel('Category')
    axes[i].set_ylabel('So luong san pham')
    axes[i].tick_params(axis='x', labelrotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Status

# %%
# vẽ biểu đồ cột phân phối số lượng đơn hàng theo từng status trong sale_order.csv
import pandas as pd
import matplotlib.pyplot as plt

sale_order_df = pd.read_csv('export_csv/sale_order.csv')
status_counts = sale_order_df['status'].value_counts()

plt.figure(figsize=(8, 5))
sns.barplot(x=status_counts.index, y=status_counts.values, palette='viridis')
plt.xlabel('Status')
plt.ylabel('Number of Orders')
plt.title('Number of Orders by Status')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_39296\3547701979.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=status_counts.index, y=status_counts.values, palette='viridis')

# %% [markdown]
# ### Gender

# %%
# ve biểu đồ cột cho số lượng đơn hàng theo từng giới tính trong customer.csv
import pandas as pd
import matplotlib.pyplot as plt

customer_df = pd.read_csv('export_csv/customer.csv')
gender_counts = customer_df['gender'].value_counts()    

plt.figure(figsize=(8, 5))
sns.barplot(x=gender_counts.index, y=gender_counts.values, palette='viridis')
plt.xlabel('Gender')
plt.ylabel('Number of Customers')   
plt.title('Number of Customers by Gender')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_39296\3296328044.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=gender_counts.index, y=gender_counts.values, palette='viridis')

# %% [markdown]
# ### Top 10 category

# %%
# top 10 category có nhiều sản phẩm nhất trong product.csv
import pandas as pd
product_df = pd.read_csv("export_csv/product.csv")
product_category_df = pd.read_csv("export_csv/product_category.csv")
merged_df = product_df.merge(
    product_category_df[['category_id', 'category_name']],
    on='category_id',
    how='left'
)
category_counts = (
    merged_df.groupby(['category_id', 'category_name'])
    .size()
    .reset_index(name='product_count')
    .sort_values(by='product_count', ascending=False)
    .head(10)
)
category_counts['category_name'] = category_counts['category_name'].fillna('Unknown')
category_counts['label'] = category_counts['category_name'] + ' (' + category_counts['product_count'].astype(str) + ')'
plt.figure(figsize=(12, 6))
sns.barplot(data=category_counts, x='label', y='product_count', palette='viridis')
plt.xlabel('Category')
plt.ylabel('Number of Products')
plt.title('Top 10 Categories with Most Products')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_39296\846131764.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=category_counts, x='label', y='product_count', palette='viridis')

# %% [markdown]
# ### Top 10 Brands with Most Purchases

# %%
# top 10 brand nhiều người mua nhất theo brand_name trong sale_order_line.csv, cần merge với product.csv và brand.csv để lấy brand_name
import pandas as pd
product_df = pd.read_csv("export_csv/product.csv")
brand_df = pd.read_csv("export_csv/brand.csv")
sale_order_line_df = pd.read_csv("export_csv/sale_order_line.csv")
merged_df = sale_order_line_df.merge(
    product_df[['product_id', 'brand_id']],
    on='product_id',
    how='left'
).merge(
    brand_df[['brand_id', 'brand_name']],
    on='brand_id',
    how='left'
)
brand_counts = (
    merged_df.groupby(['brand_id', 'brand_name'])
    .size()
    .reset_index(name='purchase_count')
    .sort_values(by='purchase_count', ascending=False)
    .head(10)
)
brand_counts['brand_name'] = brand_counts['brand_name'].fillna('Unknown')
brand_counts['label'] = brand_counts['brand_name'] + ' (' + brand_counts['purchase_count'].astype(str) + ')'
plt.figure(figsize=(12, 6))
sns.barplot(data=brand_counts, x='label', y='purchase_count', palette='viridis')
plt.xlabel('Brand')
plt.ylabel('Number of Purchases')
plt.title('Top 10 Brands with Most Purchases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_39296\3883592738.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=brand_counts, x='label', y='purchase_count', palette='viridis')

# %%
# số lần mua hàng trung bình của mỗi khách hàng trong sale_order.csv, cần merge với customer.csv để lấy thông tin khách hàng
import pandas as pd 
sale_order_df = pd.read_csv('export_csv/sale_order.csv')
customer_df = pd.read_csv('export_csv/customer.csv')
merged_df = sale_order_df.merge(
    customer_df[['user_id', 'age', 'gender']],
    on='user_id',   
    how='left'
)
purchase_counts = merged_df.groupby('user_id').size().reset_index(name='purchase_count')
average_purchases = purchase_counts['purchase_count'].mean()
print(f'So lan mua hang trung binh cua moi khach hang: {average_purchases:.2f}')
# Out:
# So lan mua hang trung binh cua moi khach hang: 5.54

# %%
# số lần mỗi product được mua trong sale_order_line.csv, cần merge với product.csv để lấy thông tin sản phẩm
import pandas as pd
product_df = pd.read_csv("export_csv/product.csv")
sale_order_line_df = pd.read_csv("export_csv/sale_order_line.csv")
merged_df = sale_order_line_df.merge(
    product_df[['product_id']],
    on='product_id',
    how='left'
)
product_purchase_counts = merged_df.groupby(['product_id']).size().reset_index(name='purchase_count').sort_values(by='purchase_count', ascending=False)
print(product_purchase_counts.head(10))
# Out:
#      product_id  purchase_count
# 130        1000            9614
# 47          473            6995
# 139        1012            6158
# 188        1182            5307
# 138        1011            5098
# 732        9306            4713
# 654        6144            4637
# 70          674            4309
# 145        1023            4207
# 140        1014            4034

# %% [markdown]
# ### Number of Orders by Month

# %%
# phân bố theo thời gian tạo đơn hàng trong sale_order.csv, vẽ biểu đồ cột số lượng đơn hàng theo tháng
import pandas as pd
sale_order_df = pd.read_csv('export_csv/sale_order.csv')
sale_order_df['order_date'] = pd.to_datetime(sale_order_df['order_date'])
sale_order_df['month'] = sale_order_df['order_date'].dt.to_period('M')
monthly_order_counts = sale_order_df.groupby('month').size().reset_index(name='order_count')
plt.figure(figsize=(12, 6))
sns.barplot(x=monthly_order_counts['month'].astype(str), y=monthly_order_counts['order_count'], palette='viridis')
plt.xlabel('Month')
plt.ylabel('Number of Orders')
plt.title('Number of Orders by Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_39296\2858967142.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=monthly_order_counts['month'].astype(str), y=monthly_order_counts['order_count'], palette='viridis')

# %% [markdown]
# ### Top 10 Days with Most Orders

# %%
# Top 10 ngày có nhiều đơn hàng nhất trong sale_order.csv
import pandas as pd
sale_order_df = pd.read_csv('export_csv/sale_order.csv')
sale_order_df['order_date'] = pd.to_datetime(sale_order_df['order_date'])
daily_order_counts = sale_order_df.groupby(sale_order_df['order_date'].dt.date).size().reset_index(name='order_count').sort_values(by='order_count', ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=daily_order_counts['order_date'].astype(str), y=daily_order_counts['order_count'], palette='viridis')
plt.xlabel('Order Date')
plt.ylabel('Number of Orders')
plt.title('Top 10 Days with Most Orders')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_39296\2168735385.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=daily_order_counts['order_date'].astype(str), y=daily_order_counts['order_count'], palette='viridis')

# %% [markdown]
# ### Top 5 Hours with Most Orders

# %%
# Top 5 giờ có nhiều đơn hàng nhất trong sale_order.csv
import pandas as pd 
sale_order_df = pd.read_csv('export_csv/sale_order.csv')
sale_order_df['order_date'] = pd.to_datetime(sale_order_df['order_date'])
sale_order_df['hour'] = sale_order_df['order_date'].dt.hour
hourly_order_counts = sale_order_df.groupby('hour').size().reset_index(name='order_count').sort_values(by='order_count', ascending=False).head(5)
plt.figure(figsize=(12, 6))
sns.barplot(x=hourly_order_counts['hour'], y=hourly_order_counts['order_count'], palette='viridis')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Orders')
plt.title('Top 5 Hours with Most Orders')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_39296\494404872.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=hourly_order_counts['hour'], y=hourly_order_counts['order_count'], palette='viridis')

# %% [markdown]
# ### Number of Orders by Day of Week

# %%
# phân bố thời gian theo ngày trong tuần trong sale_order.csv
import pandas as pd
sale_order_df = pd.read_csv('export_csv/sale_order.csv')
sale_order_df['order_date'] = pd.to_datetime(sale_order_df['order_date'])
sale_order_df['day_of_week'] = sale_order_df['order_date'].dt.day_name()
day_of_week_counts = sale_order_df['day_of_week'].value_counts().reindex([
    'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'
])
plt.figure(figsize=(12, 6))
sns.barplot(x=day_of_week_counts.index, y=day_of_week_counts.values, palette='viridis')
plt.xlabel('Day of Week')
plt.ylabel('Number of Orders')
plt.title('Number of Orders by Day of Week')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_39296\2928939946.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=day_of_week_counts.index, y=day_of_week_counts.values, palette='viridis')

# %% [markdown]
# ### Number of Orders by City/Province

# %%
# phân bố theo đia điểm tạo đơn hàng trong sale_order.csv, vẽ biểu đồ cột số lượng đơn hàng theo city
import pandas as pd
sale_order_df = pd.read_csv('export_csv/sale_order.csv')
city_counts = sale_order_df['shipping_province_name'].value_counts().head(5)
plt.figure(figsize=(12, 6))
sns.barplot(x=city_counts.index, y=city_counts.values, palette='viridis')
plt.xlabel('City')
plt.ylabel('Number of Orders')
plt.title('Number of Orders by City/Province')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_39296\3141515840.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=city_counts.index, y=city_counts.values, palette='viridis')

# %% [markdown]
# ## 7. Assumption

# %% [markdown]
# ### Shipping Province
# - Hypothesis: Người dùng trong cùng shipping_province có phân phối danh mục mua hàng tương đồng
# - Why: Do khí hậu + availability + văn hóa tiêu dùng
# - Validate:
#     - So sánh distribution category_name theo shipping_province_name
#     - Dùng cosine similarity giữa các tỉnh
# Impact:
#     - Feature: shipping_province_name

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

# ======================
# 1. Chuẩn bị dimension tables (set index để join nhanh)
# ======================
product_map = product_df.set_index('product_id')['category_id']
category_map = product_category_df.set_index('category_id')['category_name']
order_map = sale_order_df.set_index('sale_order_id')['shipping_province_name']

# ======================
# 2. Map thay vì merge (NHANH hơn nhiều)
# ======================
df = sale_order_line_df.copy()

df['category_id'] = df['product_id'].map(product_map)
df['category_name'] = df['category_id'].map(category_map)
df['shipping_province_name'] = df['sale_order_id'].map(order_map)

# Drop NA sớm để giảm size
df = df.dropna(subset=['category_name', 'shipping_province_name'])

# ======================
# 3. Lấy Top provinces (giảm data sớm)
# ======================
top_provinces = (
    df['shipping_province_name']
    .value_counts()
    .head(5)
    .index
)

df = df[df['shipping_province_name'].isin(top_provinces)]

# ======================
# 4. Groupby thay vì pivot_table (nhanh hơn)
# ======================
province_dist = (
    df.groupby(['shipping_province_name', 'category_name'])['sale_order_id']
    .count()
    .unstack(fill_value=0)
)

# ======================
# 5. Normalize (vectorized, OK)
# ======================
province_dist_pct = province_dist.div(province_dist.sum(axis=1), axis=0)

# ======================
# 6. Top categories (giảm dimension)
# ======================
top_categories = (
    province_dist_pct.sum(axis=0)
    .nlargest(10)
    .index
)

filtered_plot_df = province_dist_pct[top_categories]

# ======================
# 7. Cosine similarity
# ======================
similarity_matrix = cosine_similarity(province_dist_pct.values)

similarity_df = pd.DataFrame(
    similarity_matrix,
    index=province_dist_pct.index,
    columns=province_dist_pct.index
)

# ======================
# 8. Visualization
# ======================
plt.figure(figsize=(12, 10))
sns.heatmap(similarity_df, cmap='YlGnBu', annot=False)
plt.title('Độ tương đồng về danh mục mua sắm giữa các tỉnh thành')
plt.show()

filtered_plot_df.T.plot(kind='bar', figsize=(15, 6))
plt.title('So sánh cơ cấu Top 10 danh mục (%) giữa các tỉnh trọng điểm')
plt.ylabel('Tỷ lệ mua sắm')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Kết luận
# - Việc phân tích dữ liệu cho thấy giả thuyết "Người dùng trong cùng tỉnh thành có phân phối danh mục mua hàng tương đồng" là hoàn toàn có cơ sở và mang tính thực tế cao.
# - Các cụm tương đồng: * Bắc Ninh - Nam Định - Thái Bình: Có sự tương đồng rất sâu sắc (màu xanh đậm), phản ánh thói quen tiêu dùng khá đồng nhất của các tỉnh khu vực phía Bắc.
# - TP.HCM và Hà Nội: Dù là hai đầu cầu đất nước, sự tương đồng vẫn rất cao, cho thấy lối sống đô thị hóa (urban lifestyle) dẫn đến nhu cầu hàng hóa tương tự nhau.

# %% [markdown]
# - Biểu đồ cột (Bar chart) cho thấy rõ lý do tại sao độ tương đồng lại cao như vậy:
#
# - Thống trị bởi nhu yếu phẩm: Danh mục "Dầu ăn" và "Giặt giũ" chiếm tỷ trọng áp đảo ở tất cả các tỉnh. Đây là các mặt hàng thiết yếu, ít bị ảnh hưởng bởi biến động vùng miền.
#
# - Sự khác biệt tinh tế: * Nhóm mẹ và bé: Các danh mục như Sữa bột cho bé, Sữa bột, Nước rửa bình cho thấy sự ổn định về nhu cầu ở cả 5 tỉnh thành trọng điểm.

# %% [markdown]
# ### Age group and gender
# - Hypothesis: Người dùng có cùng nhóm tuổi (age_group) và giới tính (gender) có phân phối danh mục mua hàng (category_name) tương đồng hơn so với toàn bộ population
# - Why:
#     - Sở thích tiêu dùng khác nhau theo:
#         - độ tuổi (gen Z vs gen X)
#         - giới tính (một số ngành hàng có bias)
#     - Marketing segmentation thường dựa trên demographic

# %%
import numpy as np
from scipy.spatial.distance import jensenshannon

product_category_df = pd.read_csv("export_csv/product_category.csv")
sale_order_df = pd.read_csv("export_csv/sale_order.csv")
sale_order_line_df = pd.read_csv("export_csv/sale_order_line.csv")
product_df = pd.read_csv("export_csv/product.csv")
customer_df = pd.read_csv("export_csv/customer.csv")

merged_df = sale_order_line_df.merge(
    sale_order_df[['sale_order_id', 'user_id']],
    on='sale_order_id',
    how='left'
).merge(
    customer_df[['user_id', 'age', 'gender']],
    on='user_id',
    how='left'
).merge(
    product_df[['product_id', 'category_id']],
    on='product_id',
    how='left'
).merge(
    product_category_df[['category_id', 'category_name']],
    on='category_id',
    how='left'
)

# ======================
# 1. GLOBAL DISTRIBUTION
# ======================
global_dist = (
    merged_df['category_name']
    .value_counts(normalize=True)
    .sort_index()
)

# ======================
# 2. DEMOGRAPHIC DISTRIBUTION
# ======================
group_dist = (
    merged_df.groupby(['age', 'gender'])['category_name']
    .value_counts(normalize=True)
    .unstack(fill_value=0)
)

# align columns
group_dist = group_dist.reindex(columns=global_dist.index, fill_value=0)

# ======================
# 3. COMPUTE DIVERGENCE
# ======================
results = []

for idx, row in group_dist.iterrows():
    js_div = jensenshannon(row.values, global_dist.values)
    
    results.append({
        'age_group': idx[0],
        'gender': idx[1],
        'js_divergence': js_div
    })

div_df = pd.DataFrame(results)

# ======================
# 4. SORT & VIEW
# ======================
div_df = div_df.sort_values(by='js_divergence', ascending=False)

print(div_df.head())
# Out:
#     age_group  gender  js_divergence
# 83         59    Male       0.681897
# 79         57    Male       0.676242
# 81         58    Male       0.660748
# 82         59  Female       0.650191
# 80         58  Female       0.546869

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.bar(range(len(div_df)), div_df['js_divergence'])
plt.title("Divergence from Global Distribution (by demographic group)")
plt.xlabel("Group index")
plt.ylabel("JS Divergence")
plt.show()

# %% [markdown]
# ### Nhận xét:
# Giả thuyết "Người dùng cùng nhóm tuổi và giới tính có phân phối mua hàng tương đồng (khác biệt so với quần thể chung)" được xác nhận mạnh mẽ thông qua chỉ số Jensen-Shannon (JS) Divergence.
#
# - Chỉ số JS Divergence cao: Biểu đồ cho thấy có những nhóm nhân khẩu học đạt mức divergence lên tới 0.6 - 0.7. Trong thống kê, JS Divergence càng cao nghĩa là phân phối của nhóm đó càng khác biệt xa so với phân phối tổng (Global Distribution).
#
# - Minh chứng từ dữ liệu: Các nhóm nam giới lớn tuổi (ví dụ: Group Index 83, 79, 81 tương ứng với độ tuổi 57-59) có sự khác biệt cực kỳ lớn so với mức trung bình của toàn bộ sàn. Điều này chứng tỏ họ không mua sắm những thứ mà "đám đông" thường mua (như tã sữa hay dầu ăn với số lượng lớn), mà tập trung vào các danh mục đặc thù.
#
# - Khác với sự tương đồng (Similarity) ở giả thuyết địa lý, JS Divergence đo lường "cá tính" của phân khúc:
#
#     - Nhóm lệch cao (High Divergence): Thường là các nhóm có hành vi mua sắm rất tập trung (niche). Ví dụ: Nam giới 59 tuổi có thể chỉ tập trung vào đồ điện tử, dụng cụ sửa chữa hoặc thực phẩm chức năng, thay vì giỏ hàng đa dạng nhu yếu phẩm như nhóm hộ gia đình.
#
#     - Nhóm lệch thấp (Low Divergence): Các nhóm ở phía bên phải biểu đồ (JS < 0.1) có hành vi mua sắm "hòa tan" vào đám đông. Đây thường là nhóm khách hàng đại trà (Mass Market), mua sắm đủ mọi danh mục thiết yếu.
#
# - Nguyên nhân xác nhận giả thuyết:
#     - Sự ưu tiên ngành hàng (Gender Bias): Nam giới và nữ giới có xu hướng chi tiêu vào các ngành hàng khác biệt rõ rệt (ví dụ: Mỹ phẩm vs. Phụ kiện xe).
#
#     - Giai đoạn cuộc đời (Life Stages): Nhóm tuổi phản ánh nhu cầu thực tế. Gen Z (thích bắt trend, thời trang) sẽ có phân phối hàng hóa khác hoàn toàn so với Gen X (tập trung cho gia đình, sức khỏe).

# %% [markdown]
# ### Timestamp
# - Giả định về mặt thời gian: Giả định về thời điểm: Có những nhóm khách hàng chỉ tập trung mua sắm vào các khung giờ nhất định hoặc các ngày cuối tuần.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Tạo master_df nếu chưa tồn tại trong kernel
if 'master_df' not in globals():
    master_df = pd.read_csv('export_csv/sale_order.csv')

# Chuyển đổi cột ngày tháng
master_df['order_date'] = pd.to_datetime(master_df['order_date'], errors='coerce')
master_df = master_df.dropna(subset=['order_date'])

# Bóc tách các thành phần thời gian
master_df['hour'] = master_df['order_date'].dt.hour
master_df['day_of_week'] = master_df['order_date'].dt.day_name()
master_df['is_weekend'] = master_df['order_date'].dt.dayofweek.isin([5, 6]) # Thứ 7, CN

# 1. Trực quan hóa Lượng đơn hàng theo Giờ trong ngày
plt.figure(figsize=(12, 5))
sns.countplot(data=master_df, x='hour', palette='coolwarm')
plt.title('Phân bổ đơn hàng theo Giờ trong ngày (Giờ vàng)')
plt.xlabel('Giờ')
plt.ylabel('Số lượng đơn')
plt.show()

# 2. Trực quan hóa Lượng đơn hàng theo Thứ trong tuần
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
plt.figure(figsize=(12, 5))
sns.countplot(data=master_df, x='day_of_week', order=day_order, palette='magma')
plt.title('Phân bổ đơn hàng theo Ngày trong tuần')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_39296\1332265376.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=master_df, x='hour', palette='coolwarm')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_39296\1332265376.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=master_df, x='day_of_week', order=day_order, palette='magma')

# %%
# Sắp xếp dữ liệu theo user và thời gian
master_df = master_df.sort_values(['user_id', 'order_date'])

# Tính khoảng cách giữa 2 lần mua liên tiếp của cùng 1 user
master_df['days_since_last_order'] = master_df.groupby('user_id')['order_date'].diff().dt.days

# Tính chu kỳ mua hàng trung bình của hệ thống
avg_cycle = master_df['days_since_last_order'].mean()
print(f"Chu kỳ mua hàng trung bình của User: {avg_cycle:.2f} ngày")

# Trực quan hóa phân bổ chu kỳ
plt.figure(figsize=(10, 5))
sns.histplot(master_df['days_since_last_order'].dropna(), bins=30, kde=True)
plt.title('Phân bổ khoảng cách giữa các lần mua (Days)')
plt.xlim(0, 60) # Giới hạn 60 ngày để nhìn rõ hơn
plt.show()
# Out:
# Chu kỳ mua hàng trung bình của User: 39.04 ngày

# %% [markdown]
# ### Nhận xét: Phân tích hành vi mua sắm theo chiều thời gian (Time-series Analysis)
# - Dữ liệu cho thấy hành vi mua sắm của người dùng không phân bổ ngẫu nhiên mà tuân theo các quy luật sinh hoạt và chu kỳ tiêu dùng rất rõ rệt.
#
# 1. "Giờ vàng" mua sắm: Sự lên ngôi của giờ hành chính và đêm muộn
# Biểu đồ phân bổ theo giờ trong ngày tiết lộ hai đỉnh (peak) quan trọng:
#
#     - Đỉnh ban ngày (9h - 11h sáng): Đây là khung giờ mua sắm mạnh nhất. Điều này cho thấy người dùng có thói quen tranh thủ đặt hàng vào đầu giờ làm việc hoặc sau khi đã hoàn thành các công việc gia đình buổi sáng.
#
#     - Đỉnh buổi tối (20h - 22h đêm): Lượng đơn hàng tăng cao trở lại. Đây là thời gian nghỉ ngơi, giải trí, lúc người dùng có xu hướng lướt ứng dụng và phát sinh nhu cầu mua sắm cá nhân.
#
# 2. "Ngày vàng" trong tuần: Tập trung vào giữa tuần
# - Trái với giả định thông thường rằng người dân mua sắm nhiều vào cuối tuần, biểu đồ cho thấy:
#
#     - Cao điểm giữa tuần: Thứ Tư (Wednesday) là ngày có lượng đơn hàng cao nhất, theo sau là Thứ Ba và Thứ Năm.
#
#     - Sụt giảm cuối tuần: Lượng đơn hàng bắt đầu giảm từ Thứ Bảy và chạm đáy vào Chủ Nhật.
#
# 3. Chu kỳ tái mua hàng (Retention & Recency):
# Với chu kỳ trung bình 39.04 ngày và biểu đồ phân bổ khoảng cách:
#
#     - Tập trung ngắn hạn: Phần lớn người dùng có xu hướng quay lại mua hàng trong khoảng 0 - 12 ngày (cột đầu tiên cao vượt trội). Điều này chứng tỏ một nhóm khách hàng trung thành rất lớn có nhu cầu mua sắm nhu yếu phẩm hàng tuần.
#
#     - Điểm rơi 1 tháng: Sau khoảng 30 ngày, tần suất mua hàng giảm dần và đi ngang. Con số 39.03 ngày là một chỉ số cực kỳ quan trọng, khớp với chu kỳ nhận lương và tái mua sắm các mặt hàng hết định kỳ (như dầu ăn, bột giặt, sữa...).

# %% [markdown]
# ## 8. User Persona

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Gộp bảng (Master Data)
df_age_cat = sale_order_line_df.merge(
    product_df[['product_id', 'category_id']], on='product_id'
).merge(
    product_category_df[['category_id', 'category_name']], on='category_id'
).merge(
    sale_order_df[['sale_order_id', 'user_id']], on='sale_order_id'
).merge(
    customer_df[['user_id', 'age']], on='user_id'
)

# 2. Lọc TOP K danh mục phổ biến nhất (ví dụ K=15)
top_k = 15
top_categories = df_age_cat['category_name'].value_counts().nlargest(top_k).index
df_filtered = df_age_cat[df_age_cat['category_name'].isin(top_categories)]

# 3. Chia nhóm tuổi (Binning)
bins = [0, 18, 25, 35, 45, 60, 100]
labels = ['<18', '18-25', '26-35', '36-45', '46-60', '>60']
df_filtered['age_group'] = pd.cut(df_filtered['age'], bins=bins, labels=labels)

# 4. Tạo Pivot Table & Chuẩn hóa (%)
# Tính tỷ lệ % theo dòng (mỗi nhóm tuổi tổng là 100%)
heatmap_data = df_filtered.pivot_table(
    index='age_group', 
    columns='category_name', 
    values='product_id', 
    aggfunc='count', 
    fill_value=0
)
heatmap_data_pct = heatmap_data.div(heatmap_data.sum(axis=1), axis=0)

# 5. Vẽ Heatmap sạch sẽ
plt.figure(figsize=(14, 7))
sns.heatmap(heatmap_data_pct, annot=True, cmap='YlGnBu', fmt='.1%')
plt.title(f'Heatmap: Tỷ trọng Top {top_k} Danh mục theo Nhóm tuổi')
plt.xlabel('Danh mục sản phẩm')
plt.ylabel('Nhóm tuổi')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Case 1: Phụ nữ từ 25-30 tuổi

# %%
import pandas as pd
import numpy as np

# 1. Đọc dữ liệu
sale_order_df = pd.read_csv('export_csv/sale_order.csv')
sale_order_line_df = pd.read_csv('export_csv/sale_order_line.csv')
product_df = pd.read_csv('export_csv/product.csv')
product_category_df = pd.read_csv('export_csv/product_category.csv')
customer_df = pd.read_csv('export_csv/customer.csv')

# Chuyển đổi thời gian
sale_order_df['order_date'] = pd.to_datetime(sale_order_df['order_date'])

# 2. FEATURE ENGINEERING: Thời điểm mua sắm
sale_order_df['order_hour'] = sale_order_df['order_date'].dt.hour
sale_order_df['day_of_week'] = sale_order_df['order_date'].dt.day_name()
sale_order_df['is_weekend'] = sale_order_df['order_date'].dt.dayofweek.isin([5, 6]).astype(int)

# 3. GỘP BẢNG TỔNG HỢP (Master Interaction)
# Gộp để biết: Ai mua cái gì, ở đâu, lúc nào
master_interaction = sale_order_line_df.merge(
    sale_order_df[['sale_order_id', 'user_id', 'shipping_province_name', 'order_hour', 'day_of_week', 'is_weekend']], 
    on='sale_order_id'
).merge(
    product_df[['product_id', 'category_id']], on='product_id'
).merge(
    product_category_df[['category_id', 'category_name']], on='category_id'
).merge(
    customer_df[['user_id', 'age', 'gender']], on='user_id'
)

# 4. XÂY DỰNG CHÂN DUNG KHÁCH HÀNG (Customer Persona Table)
# Chúng ta sẽ group theo user_id để tạo các đặc trưng riêng biệt cho từng người
user_persona = master_interaction.groupby('user_id').agg(
    total_orders=('sale_order_id', 'nunique'),
    
    # top 3 categories (quan trọng)
    top_categories=('category_name', lambda x: x.value_counts().head(3).index.tolist()),
    
    # location
    common_shipping_province=('shipping_province_name', lambda x: x.mode()[0]),
    
    # time behavior
    preferred_hour=('order_hour', lambda x: x.mode()[0]),
    most_active_day=('day_of_week', lambda x: x.mode()[0]),
    
    # diversity
    n_categories=('category_name', 'nunique'),
    
    # demographic
    age=('age', 'first'),
    gender=('gender', 'first')
).reset_index()

# 5. SEGMENT: Phụ nữ 25-30 tại Hà Nội
female_segment = master_interaction[
    (master_interaction['gender'] == 'Female') & 
    (master_interaction['age'].between(25, 30)) & 
    (master_interaction['shipping_province_name'] == 'Hà Nội')
]

# ======================
# A. Top category (macro view)
# ======================
top_categories_target = (
    female_segment['category_name']
    .value_counts()
    .head(5)
)

# ======================
# B. Persona của segment (micro view)
# ======================
female_persona = female_segment.groupby('user_id').agg(
    total_orders=('sale_order_id', 'nunique'),
    top_categories=('category_name', lambda x: x.value_counts().head(3).index.tolist()),
    preferred_hour=('order_hour', lambda x: x.mode()[0]),
    most_active_day=('day_of_week', lambda x: x.mode()[0]),
    n_categories=('category_name', 'nunique')
).reset_index()

print("--- Top 5 danh mục Phụ nữ 25-30 tại Hà Nội ---")
print(top_categories_target)

print("\n--- Chân dung khách hàng (segment này) ---")
print(female_persona.head())
# Out:
# --- Top 5 danh mục Phụ nữ 25-30 tại Hà Nội ---
# category_name
# Dầu ăn            3243
# Sữa bột cho bé    2219
# Giặt giũ          1989
# Sữa bột           1554
# Mặt nạ            1187
# Name: count, dtype: int64
#
# --- Chân dung khách hàng (segment này) ---
#                                 user_id  total_orders  \
# 0  000a502a-da2c-46bf-bec8-c8d5206fa8d2             1
# 1  000c581d-3b8a-4ed2-8b94-000053f1e07e            11
# 2  00138f20-cc0e-435b-af41-6747f80668dc             4
# 3  00152520-d841-41ce-bc39-a62811663059             6
# 4  00289ec9-6576-4e14-aace-76556403dd92             4
#
#                                       top_categories  preferred_hour  \
# 0  [Sản phẩm Thực phẩm, bánh kẹo và nước giải khá...               0
# 1  [Giặt giũ, Tã, Bỉm quần, Máy hút sữa, máy hâm,...               1
# 2      [Sữa bột cho bé, Đồ uống có cồn, Nguyên liệu]               1
# 3  [Dầu ăn, Rửa chén, bát, Sản phẩm hỗ trợ tình dục]               7
# 4                     [Giặt giũ, Mặt nạ, Cafe - Trà]              15
#
#   most_active_day  n_categories
# 0          Monday             3
# 1          Friday            15
# 2       Wednesday             3
# 3        Saturday             6
# 4        Saturday            10

# %% [markdown]
# Nhận định:
# Người dùng thể hiện hành vi mua sắm đa dạng, từ tập trung (ít đa dạng danh mục) đến khám phá (đa dạng danh mục).
#
# Ngoài ra, người dùng nữ từ 25-30 tuổi tại Hà Nội thể hiện sự ưa thích mạnh mẽ đối với các sản phẩm gia dụng và chăm sóc trẻ em, cho thấy họ là người mua sắm chính trong gia đình.
#
# Ý nghĩa:
#
# - Chiến lược đề xuất cần được cá nhân hóa:
#
# - Người dùng tập trung → đề xuất sản phẩm tương tự
#
# - Người dùng khám phá → đề xuất đa dạng
# - Đề xuất đa danh mục là cần thiết do hành vi đa mục đích
# - Đặc điểm nhân khẩu học hữu ích cho các tình huống khởi đầu mới

# %% [markdown]
# ### Case 2: Nam giới từ 46-60 tuổi

# %%
import pandas as pd
import numpy as np

# 1. Đọc dữ liệu
sale_order_df = pd.read_csv('export_csv/sale_order.csv')
sale_order_line_df = pd.read_csv('export_csv/sale_order_line.csv')
product_df = pd.read_csv('export_csv/product.csv')
product_category_df = pd.read_csv('export_csv/product_category.csv')
customer_df = pd.read_csv('export_csv/customer.csv')

# Chuyển đổi thời gian
sale_order_df['order_date'] = pd.to_datetime(sale_order_df['order_date'])

# 2. FEATURE ENGINEERING: Thời điểm mua sắm
sale_order_df['order_hour'] = sale_order_df['order_date'].dt.hour
sale_order_df['day_of_week'] = sale_order_df['order_date'].dt.day_name()
sale_order_df['is_weekend'] = sale_order_df['order_date'].dt.dayofweek.isin([5, 6]).astype(int)

# 3. GỘP BẢNG TỔNG HỢP (Master Interaction)
# Gộp để biết: Ai mua cái gì, ở đâu, lúc nào
master_interaction = sale_order_line_df.merge(
    sale_order_df[['sale_order_id', 'user_id', 'shipping_province_name', 'order_hour', 'day_of_week', 'is_weekend']], 
    on='sale_order_id'
).merge(
    product_df[['product_id', 'category_id']], on='product_id'
).merge(
    product_category_df[['category_id', 'category_name']], on='category_id'
).merge(
    customer_df[['user_id', 'age', 'gender']], on='user_id'
)

# 4. XÂY DỰNG CHÂN DUNG KHÁCH HÀNG (Customer Persona Table)
# Chúng ta sẽ group theo user_id để tạo các đặc trưng riêng biệt cho từng người
male_interaction = master_interaction[
    master_interaction['gender'] == 'Male'
]

male_persona = male_interaction.groupby('user_id').agg(
    total_orders=('sale_order_id', 'nunique'),
    top_categories=('category_name', lambda x: x.value_counts().head(3).index.tolist()),
    common_shipping_province=('shipping_province_name', lambda x: x.mode()[0]),
    preferred_hour=('order_hour', lambda x: x.mode()[0]),
    most_active_day=('day_of_week', lambda x: x.mode()[0]),
    n_categories=('category_name', 'nunique'),
    age=('age', 'first'),
    gender=('gender', 'first')
).reset_index()

# 5. TRẢ LỜI CÂU HỎI CỤ THỂ: "Nam giới 46-60 ở Hà Nội mua gì nhiều nhất?"
target_group = master_interaction[
    (master_interaction['gender'] == 'Male') & 
    (master_interaction['age'].between(46, 60)) & 
    (master_interaction['shipping_province_name'] == 'Hà Nội')
]

top_categories_target = target_group['category_name'].value_counts().head(5)

print("--- Top 5 danh mục Nam giới 46-60 tại Hà Nội ưa chuộng ---")
print(top_categories_target)
print("--- Chân dung khách hàng nam ---")
print(male_persona.head())
# Out:
# --- Top 5 danh mục Nam giới 46-60 tại Hà Nội ưa chuộng ---
# category_name
# Dầu ăn            148
# Giặt giũ          107
# Sữa bột cho bé     92
# Sữa bột            76
# Mặt nạ             68
# Name: count, dtype: int64
# --- Chân dung khách hàng nam ---
#                                 user_id  total_orders  \
# 0  00061ffd-5841-4068-a4eb-91a27b078f91             5
# 1  000a4bb0-47e0-4e02-8c71-fabd8f58fd3e             4
# 2  00114c6e-945e-4816-aea1-ed8ff9b6f31c             2
# 3  0011bd8d-3bb9-4800-bf03-2daec7a24558             2
# 4  001617b8-42cf-4834-b1b7-06e5c33eeac8             4
#
#                                       top_categories common_shipping_province  \
# 0  [Tã, Bỉm dán, Giặt giũ, Quà tặng Thực phẩm, bá...               Bình Phước
# 1                      [Tẩy trang, Giặt giũ, Dầu ăn]                Hải Dương
# 2                        [Miếng lót sơ sinh, Mặt nạ]                   Hà Nội
# 3                      [Sữa bột cho bé, Nguyên liệu]              Hồ Chí Minh
# 4  [Sữa bột, Nước rửa bình, giặt xả mẹ và bé, Giặ...                   Hà Nội
#
#    preferred_hour most_active_day  n_categories  age gender
# 0              15        Saturday             3   27   Male
# 1               4        Saturday             3   33   Male
# 2              10        Saturday             2   18   Male
# 3               9          Friday             2   41   Male
# 4               6       Wednesday             4   18   Male

# %% [markdown]
# Nhận định:
# Sự khác biệt về sở thích theo danh mục giữa người dùng nam và nữ là không đáng kể, đặc biệt là đối với các sản phẩm liên quan đến gia đình.
#
# Điều này cho thấy hành vi mua sắm trong tập dữ liệu này chủ yếu do nhu cầu gia đình quyết định hơn là sở thích cá nhân.
#
# Hàm ý:
# - Giới tính là một yếu tố yếu đối với hệ thống đề xuất trong lĩnh vực này
# - Hệ thống đề xuất nên tập trung nhiều hơn vào các tín hiệu hành vi và ngữ cảnh.

# %% [markdown]
# ## 9. Baseline

# %%
# Load data
import pandas as pd
import numpy as np

sale_order_df = pd.read_csv('export_csv/sale_order.csv')
sale_order_line_df = pd.read_csv('export_csv/sale_order_line.csv')
product_df = pd.read_csv('export_csv/product.csv')
product_category_df = pd.read_csv('export_csv/product_category.csv')
customer_df = pd.read_csv('export_csv/customer.csv')

# Time features
sale_order_df['order_date'] = pd.to_datetime(sale_order_df['order_date'])
sale_order_df['order_hour'] = sale_order_df['order_date'].dt.hour
sale_order_df['day_of_week'] = sale_order_df['order_date'].dt.day_name()

# Merge master table
master_interaction = sale_order_line_df.merge(
    sale_order_df[['sale_order_id', 'user_id', 'order_date', 'order_hour', 'day_of_week']],
    on='sale_order_id'
).merge(
    product_df[['product_id', 'category_id']], on='product_id'
).merge(
    product_category_df[['category_id', 'category_name']], on='category_id'
).merge(
    customer_df[['user_id', 'age', 'gender']], on='user_id'
)

master_interaction.head()
# Out:
#    line_id                         sale_order_id  product_id  is_gift  \
# 0   237023  2dcf8a24-47d3-4eae-b7f4-82e0f91f024b       18918    False
# 1   254206  4db9f2a2-1a46-4929-abc5-5971fb493341        1014    False
# 2   237109  ccda3682-64d8-4549-aded-4a382e97c64d       15450    False
# 3   234997  57f60526-716e-4167-aa08-e1406a204c4c        1160    False
# 4   244152  64660773-bd82-43d5-a45e-67070bd72348       13785    False
#
#                                 user_id          order_date  order_hour  \
# 0  b962cb7b-c165-4b1c-8fe7-23d7042f8308 2025-11-13 11:08:00          11
# 1  9a47667d-d942-4513-806d-afa0b3cc4303 2025-12-24 09:08:00           9
# 2  964ae102-217f-4a6c-8244-4b8f79ef552f 2025-11-13 14:40:00          14
# 3  61ddf99d-fa8d-4838-8c52-8b9622ad730b 2025-11-10 22:06:00          22
# 4  d5f10769-7453-4be5-a979-8def0401f3f7 2025-11-30 07:40:00           7
#
#   day_of_week  category_id         category_name  age  gender
# 0    Thursday           95        Sữa bột cho bé   34  Female
# 1   Wednesday          177                Dầu ăn   22  Female
# 2    Thursday          141          Nước hoa nam   32    Male
# 3      Monday          177                Dầu ăn   34    Male
# 4      Sunday          216  Vệ sinh sàn, Toa lét   26  Female

# %%
# kiểm tra feature hiện có trong baseline dataset
print("Master interaction columns:")
print(master_interaction.columns.tolist())

print("\nDtypes:")
print(master_interaction.dtypes)

print("\nSample:")
display(master_interaction.head())

# nếu cần xem feature baseline dùng cho model recommendation
baseline_features = [
    'user_id',
    'category_name',
    'age',
    'gender',
    'order_date',
    'order_hour',
    'day_of_week'
]
print("\nBaseline features used:")
print(baseline_features)

# show distribution / sample cho các feature này
display(master_interaction[baseline_features].head(20))
# Out:
# Master interaction columns:
# ['line_id', 'sale_order_id', 'product_id', 'is_gift', 'user_id', 'order_date', 'order_hour', 'day_of_week', 'category_id', 'category_name', 'age', 'gender']
#
# Dtypes:
# line_id                   int64
# sale_order_id               str
# product_id                int64
# is_gift                    bool
# user_id                     str
# order_date       datetime64[us]
# order_hour                int32
# day_of_week                 str
# category_id               int64
# category_name               str
# age                       int64
# gender                      str
# dtype: object
#
# Sample:
#    line_id                         sale_order_id  product_id  is_gift  \
# 0   237023  2dcf8a24-47d3-4eae-b7f4-82e0f91f024b       18918    False
# 1   254206  4db9f2a2-1a46-4929-abc5-5971fb493341        1014    False
# 2   237109  ccda3682-64d8-4549-aded-4a382e97c64d       15450    False
# 3   234997  57f60526-716e-4167-aa08-e1406a204c4c        1160    False
# 4   244152  64660773-bd82-43d5-a45e-67070bd72348       13785    False
#
#                                 user_id          order_date  order_hour  \
# 0  b962cb7b-c165-4b1c-8fe7-23d7042f8308 2025-11-13 11:08:00          11
# 1  9a47667d-d942-4513-806d-afa0b3cc4303 2025-12-24 09:08:00           9
# 2  964ae102-217f-4a6c-8244-4b8f79ef552f 2025-11-13 14:40:00          14
# 3  61ddf99d-fa8d-4838-8c52-8b9622ad730b 2025-11-10 22:06:00          22
# 4  d5f10769-7453-4be5-a979-8def0401f3f7 2025-11-30 07:40:00           7
#
#   day_of_week  category_id         category_name  age  gender
# 0    Thursday           95        Sữa bột cho bé   34  Female
# 1   Wednesday          177                Dầu ăn   22  Female
# 2    Thursday          141          Nước hoa nam   32    Male
# 3      Monday          177                Dầu ăn   34    Male
# 4      Sunday          216  Vệ sinh sàn, Toa lét   26  Female
# Baseline features used:
# ['user_id', 'category_name', 'age', 'gender', 'order_date', 'order_hour', 'day_of_week']
#                                  user_id          category_name  age  gender  \
# 0   b962cb7b-c165-4b1c-8fe7-23d7042f8308         Sữa bột cho bé   34  Female
# 1   9a47667d-d942-4513-806d-afa0b3cc4303                 Dầu ăn   22  Female
# 2   964ae102-217f-4a6c-8244-4b8f79ef552f           Nước hoa nam   32    Male
# 3   61ddf99d-fa8d-4838-8c52-8b9622ad730b                 Dầu ăn   34    Male
# 4   d5f10769-7453-4be5-a979-8def0401f3f7   Vệ sinh sàn, Toa lét   26  Female
# 5   c0eef819-3b58-41b8-b430-413e3760191e                 Dầu ăn   27    Male
# 6   c0eef819-3b58-41b8-b430-413e3760191e            Nguyên liệu   27    Male
# 7   225bf985-ae0d-4601-95bd-5b735db3d271    Thực phẩm chức năng   27    Male
# 8   7d861224-9dbe-4337-877e-29fc865154cb   Vệ sinh sàn, Toa lét   24  Female
# 9   57ecb9b3-1316-42c5-a963-10032012bc56         Đồ uống có cồn   32  Female
# 10  0455635f-db69-48e5-9c8f-19acf9270a69         Sữa bột cho bé   20  Female
# 11  73b6691e-8164-4a0c-84cc-ebce170ab739           Bánh - Snack   30  Female
# 12  7ec937f1-b904-44a1-8f88-225bb03e098a  Điện thoại Smartphone   30    Male
# 13  b14c5f1e-601f-499a-9c24-bc2881e64526              Tẩy trang   18  Female
# 14  ad7f05c5-8b77-4d02-b8f6-3baad3a075e1                 Mặt nạ   33    Male
# 15  2f392013-9a4f-4fd3-84cd-2be77629343a               Sữa nước   32    Male
# 16  c1b290a6-3b70-43b2-a653-072af0c553bd            Nguyên liệu   30    Male
# 17  dde83e5d-c9a2-4c82-b085-469e56c614d9         Sữa bột cho bé   33  Female
# 18  d9e5fd38-ebc6-4b97-a490-56c87b9b1595              Tẩy trang   40    Male
# 19  1899de1d-5dbc-4db9-88e3-522e07fa9e4a            Nguyên liệu   18  Female
#
#             order_date  order_hour day_of_week
# 0  2025-11-13 11:08:00          11    Thursday
# 1  2025-12-24 09:08:00           9   Wednesday
# 2  2025-11-13 14:40:00          14    Thursday
# 3  2025-11-10 22:06:00          22      Monday
# 4  2025-11-30 07:40:00           7      Sunday
# 5  2025-11-30 12:20:00          12      Sunday
# 6  2025-11-30 12:20:00          12      Sunday
# 7  2025-12-12 05:09:00           5      Friday
# 8  2025-12-15 10:50:00          10      Monday
# 9  2025-12-15 12:16:00          12      Monday
# 10 2025-12-28 11:48:00          11      Sunday
# 11 2025-11-14 08:12:00           8      Friday
# 12 2025-11-14 10:03:00          10      Friday
# 13 2025-11-30 23:40:00          23      Sunday
# 14 2025-12-01 01:09:00           1      Monday
# 15 2025-11-14 11:24:00          11      Friday
# 16 2025-12-15 15:49:00          15      Monday
# 17 2025-12-01 11:41:00          11      Monday
# 18 2025-11-14 15:16:00          15      Friday
# 19 2025-11-12 12:20:00          12   Wednesday

# %%
import numpy as np
import pandas as pd

def add_age_group(df):
    df = df.copy()
    
    bins = [0, 18, 25, 35, 45, 60, 100]
    labels = ['<18', '18-25', '26-35', '36-45', '46-60', '>60']
    
    df['age_group'] = pd.cut(
        df['age'],
        bins=bins,
        labels=labels,
        right=True,          # (a, b]
        include_lowest=True  # include 0
    )
    
    return df

# %%
def temporal_split(df):
    df = df.sort_values('order_date')
    
    test_df = df.groupby('user_id').tail(1)
    train_df = df.drop(test_df.index)
    
    return train_df, test_df

# %%
def build_distributions(train_df, alpha=10):
    
    # Global distribution
    # Đây là phân phối chung của tất cả khách hàng, không phân theo nhóm nào
    global_dist = train_df['category_name'].value_counts(normalize=True)
    
    # Segment count
    # Đây là phân phối của từng nhóm khách hàng
    seg = train_df.groupby(
        ['gender', 'age_group', 'category_name']
    ).size().reset_index(name='count')
    
    # Tổng count mỗi segment 
    seg_total = seg.groupby(['gender', 'age_group'])['count'].transform('sum')
    
    # Map global vào
    # Đây là bước quan trọng để tính lift sau này, chúng ta cần biết mỗi segment đang mua category nào so với global
    seg['global_prob'] = seg['category_name'].map(global_dist)
    
    # Smoothed probability
    # Công thức smoothing để tránh overfitting với những segment nhỏ, alpha càng lớn thì càng gần global
    seg['prob'] = (seg['count'] + alpha * seg['global_prob']) / (seg_total + alpha)
    
    # Stable lift (log)
    # Công thức tính lift đã được log để ổn định hơn, tránh chia cho số rất nhỏ
    seg['lift'] = np.log1p(seg['prob'] / (seg['global_prob'] + 1e-6))
    
    return global_dist, seg

# %%
def analyze_lift(segment_dist, top_k=10):
    
    print("Top lift (overall):")
    display(
        segment_dist.sort_values('lift', ascending=False)[
            ['gender', 'age_group', 'category_name', 'lift']
        ].head(top_k)
    )
    
    print("\nLowest lift:")
    display(
        segment_dist.sort_values('lift', ascending=True)[
            ['gender', 'age_group', 'category_name', 'lift']
        ].head(top_k)
    )
    
    print("\nAvg lift per category:")
    display(
        segment_dist.groupby('category_name')['lift']
        .mean()
        .sort_values(ascending=False)
        .head(top_k)
    )

# %%
# Xem lift của từng danh mục
analyze_lift(segment_dist, top_k=15)
# Out:
# Top lift (overall):
#       gender age_group                      category_name      lift
# 487   Female     46-60                 Giường, Nệm, Chiếu  2.351824
# 580     Male       <18              Các chất tẩy rửa khác  1.817902
# 1092    Male     46-60     Sữa cho mẹ mang thai, sau sinh  1.789518
# 1043    Male     46-60          Dụng cụ lưu trữ thực phẩm  1.748144
# 636     Male       <18  Sản phẩm Sức khỏe và sắc đẹp khác  1.398994
# 514   Female     46-60              Phụ kiện di động khác  1.330418
# 499   Female     46-60                  Máy lọc không khí  1.314190
# 1016    Male     36-45                             Đồ lót  1.300649
# 1083    Male     46-60           Sản phẩm Thời trang khác  1.284448
# 1074    Male     46-60  Phụ kiện nhà bếp và phòng ăn khác  1.251121
# 1086    Male     46-60                   Sản phẩm khử mùi  1.227481
# 525   Female     46-60  Sản phẩm Sức khỏe và sắc đẹp khác  1.166909
# 496   Female     46-60               Lò nướng, Lò vi sóng  1.164296
# 606     Male       <18                  Miếng lót sơ sinh  1.146984
# 486   Female     46-60                       Giày Chạy Bộ  1.145977
# Lowest lift:
#       gender age_group                category_name      lift
# 1067    Male     46-60                 Ngũ cốc, Bột  0.167760
# 456   Female     46-60               Bàn ủi/ bàn là  0.170513
# 1003    Male     36-45                 Tã người lớn  0.208233
# 624     Male       <18        Phụ kiện di động khác  0.242763
# 459   Female     46-60  Bình sữa, Phụ kiện, Ty ngậm  0.245691
# 1111    Male     46-60   USB, Củ sạc , Cổng kết nối  0.247490
# 60    Female       <18    Phụ kiện chăm sóc cá nhân  0.254966
# 32    Female       <18                 Giày Chạy Bộ  0.265060
# 593     Male       <18         Ghế ngồi ôtô, xe máy  0.270896
# 1104    Male     46-60               Trang điểm mắt  0.275165
# 174   Female     18-25    Phụ kiện chăm sóc cá nhân  0.280159
# 788     Male     18-25                       Đồ lót  0.323630
# 807     Male     26-35        Các chất tẩy rửa khác  0.336044
# 953     Male     36-45                Máy tính bảng  0.340436
# 693     Male     18-25        Các chất tẩy rửa khác  0.346304
# Avg lift per category:
# category_name
# Dụng cụ lưu trữ thực phẩm            0.804118
# Giường, Nệm, Chiếu                   0.800804
# Sản phẩm Sức khỏe và sắc đẹp khác    0.769855
# Sữa cho mẹ mang thai, sau sinh       0.767981
# Các chất tẩy rửa khác                0.762982
# Máy lọc không khí                    0.762221
# Bánh trung thu                       0.757189
# Phụ kiện nhà bếp và phòng ăn khác    0.754814
# Phụ kiện di động khác                0.745816
# Miếng lót sơ sinh                    0.742560
# Ăn dặm                               0.738186
# Giày Chạy Bộ                         0.736900
# Đèn, Thiết bị chiếu sáng             0.733928
# Sản phẩm khử mùi                     0.731699
# Tai nghe                             0.730103
# Name: lift, dtype: float64

# %%
# Hàm xây dựng preference vector cho mỗi user dựa trên lịch sử mua hàng của họ
def build_user_pref(train_df):
    user_pref = train_df.groupby(['user_id', 'category_name']).size()
    
    # normalize per user
    user_pref = user_pref / user_pref.groupby('user_id').sum()
    
    return user_pref.to_dict()

# %%
# Hàm xây dựng dictionary để lookup lift của mỗi segment nhanh chóng
def build_segment_dict(segment_dist):
    return segment_dist.set_index(
        ['gender', 'age_group', 'category_name']
    ).to_dict('index')

# %%
# Hàm đề xuất sản phẩm cho một user cụ thể dựa trên 4 yếu tố: hành vi cá nhân, segment, lift và global
def recommend(
    user_id,
    user_row,
    user_pref,
    segment_dict,
    global_dist,
    categories,
    top_k=5
):
    gender = user_row['gender']
    age = user_row['age']
    
    # age group
    if age <= 25:
        age_group = 'young'
    elif age <= 35:
        age_group = 'adult'
    else:
        age_group = 'older'
    
    scores = {}
    
    for cat in categories:
        
        # --- USER BEHAVIOR ---
        user_score = user_pref.get((user_id, cat), 0)
        
        # --- SEGMENT ---
        key = (gender, age_group, cat)
        
        if key in segment_dict:
            data = segment_dict[key]
            seg_score = data['prob']
            lift_score = data['lift']
        else:
            seg_score = global_dist.get(cat, 1e-6)
            lift_score = 0
        
        # --- GLOBAL ---
        global_score = global_dist.get(cat, 1e-6)
        
        # HYBRID SCORE
        scores[cat] = (
            0.5 * user_score +
            0.3 * seg_score +
            0.2 * lift_score +
            0.1 * global_score
        )
    
    return sorted(scores, key=scores.get, reverse=True)[:top_k]

# %%
def evaluate(test_df, recommender_inputs, user_last_dict, k=5):
    user_pref, segment_dict, global_dist, categories = recommender_inputs
    
    hits = 0
    total = 0
    mrr = 0
    
    for _, row in test_df.iterrows():
        user_id = row['user_id']
        true_cat = row['category_name']
        
        user_row = user_last_dict.get(user_id)
        if user_row is None:
            continue
        
        recs = recommend(
            user_id,
            user_row,
            user_pref,
            segment_dict,
            global_dist,
            categories,
            top_k=k
        )
        
        if true_cat in recs:
            hits += 1
            rank = recs.index(true_cat) + 1
            mrr += 1 / rank
        
        total += 1
    
    return {
        f'Precision@{k}': hits / total,
        f'MRR@{k}': mrr / total
    }

# %%
# ===== PREPROCESS =====
df = add_age_group(master_interaction)

# ===== SPLIT =====
train_df, test_df = temporal_split(df)

# ===== BUILD =====
global_dist, segment_dist = build_distributions(train_df)
segment_dict = build_segment_dict(segment_dist)
user_pref = build_user_pref(train_df)

categories = train_df['category_name'].unique()

recommender_inputs = (user_pref, segment_dict, global_dist, categories)

# ===== PRECOMPUTE USER LAST =====
user_last = train_df.sort_values('order_date').groupby('user_id').tail(1)
user_last_dict = user_last.set_index('user_id').to_dict('index')

# ===== EVALUATE =====
metrics = evaluate(test_df, recommender_inputs, user_last_dict, k=5)

print(metrics)
# Out:
# {'Precision@5': 0.2792933186791555, 'MRR@5': 0.1488607470349848}

# %%
print(recommend(user_id='6fe93780-0ded-44a9-8ec3-93927f3cc1c3', user_row=user_last_dict['6fe93780-0ded-44a9-8ec3-93927f3cc1c3'], user_pref=user_pref, segment_dict=segment_dict, global_dist=global_dist, categories=categories, top_k=5))
# Out:
# ['Dầu ăn', 'Giặt giũ', 'Dầu gội, Dầu xả', 'Sữa nước', 'Tã, Bỉm quần']

# %%
print(recommend(user_id='4f4aeebb-80f0-45d4-a4f3-e347b87b2e2e', user_row=user_last_dict['4f4aeebb-80f0-45d4-a4f3-e347b87b2e2e'], user_pref=user_pref, segment_dict=segment_dict, global_dist=global_dist, categories=categories, top_k=5))
# Out:
# ['Quà tặng Thực phẩm, bánh kẹo và nước giải khát', 'Dầu ăn', 'Rửa chén, bát', 'Cafe - Trà', 'Thực phẩm khác']

# %%
print(recommend(user_id='8bd955d9-ba8c-47c9-bdf4-9c548294f6e9', user_row=user_last_dict['8bd955d9-ba8c-47c9-bdf4-9c548294f6e9'], user_pref=user_pref, segment_dict=segment_dict, global_dist=global_dist, categories=categories, top_k=5))
# Out:
# ['Nước rửa bình, giặt xả mẹ và bé', 'Dầu gội, Dầu xả', 'Dầu ăn', 'Sữa bột', 'Sữa bột cho bé']
